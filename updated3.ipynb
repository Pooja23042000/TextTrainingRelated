# %%
import os
import xml.etree.ElementTree as ET
import pdb
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Out:
# WARNING:tensorflow:From C:\Users\pooja\anaconda3\envs\textanalysis\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def build_classification_tree(node):
    #pdb.set_trace()
    classification_symbol = node.find('classification-symbol').text
    title_text_list=[]
    cpc_text_list=[]
    title_parts = node.findall('class-title/title-part')
    for title_part in title_parts:
        text_tag = title_part.find('text')
        if text_tag is not None:
            text= text_tag.text
            title_text_list.append(text)
            
    cpc_text = node.findall('class-title/title-part/CPC-specific-text')
    for cpc_part in cpc_text:
        text_tag = cpc_part.find('text')
        if text_tag is not None:
            text= text_tag.text
            cpc_text_list.append(text)

    classification_def = title_text_list + cpc_text_list
    classification_def = [def_item for def_item in classification_def if def_item is not None]
    classification_def=';'.join(classification_def)
    children = node.findall('classification-item')

    if children:
        child_results = [build_classification_tree(child) for child in children]
        return (classification_symbol, classification_def, child_results)
    else:
        return (classification_symbol, classification_def)

# %%
# Function to process XML files in a folder
def process_xml_files_in_folder(folder_path):
    #pdb.set_trace()
    classification_trees = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.xml'):
            xml_file_path = os.path.join(folder_path, filename)
            tree = ET.parse(xml_file_path)
            root = tree.getroot()
            baseroot = root[0]  # Assuming the structure is consistent
            classification_tree = build_classification_tree(baseroot)
            #print(classification_tree)
            classification_trees.append((filename, classification_tree))
    return classification_trees

# %%
# Full path to folder containing XML files
folder_path1 = os.path.join(os.path.expanduser("~"), "Downloads", "CPCSchemeXML202401")
folder_path2 = os.path.join(os.path.expanduser("~"), "Downloads", "CPCSchemeXML202401","ClassXMLfiles")
# Process XML files in the folder
classification_trees = process_xml_files_in_folder(folder_path1)
c_tree=process_xml_files_in_folder(folder_path2)

# Print classification trees
#classification_trees

# %%
import pdb

def get_child(child_list, prev_symbols, result):
    #pdb.set_trace()
    
    for child_tuple in child_list:
        symbol = child_tuple[0]
        definition = child_tuple[1]
        result[symbol] = prev_symbols + [definition]
        
        if len(child_tuple) == 3:
            sub_child = child_tuple[2]
            get_child(sub_child, prev_symbols + [definition], result)

    return result

# %%
withSlashDict = {}

# %%
for i in range(len(c_tree)):
    #child_list_example =[classification_trees[i][1]]
    child_list_example1 =[c_tree[i][1]]
    
    # Calling the function
    get_child(child_list_example1, [], withSlashDict)

# %%
for i in range(len(classification_trees)):
    prev=classification_trees[i][0].replace('.xml','')[-4:-1]
    child_list_example =[classification_trees[i][1]]
    #print(prev_sym)
    # Calling the function
    get_child(child_list_example, withSlashDict[prev], withSlashDict)

# %%
withSlashDict
# Out:
# {'A': ['HUMAN NECESSITIES'],
#  'A01': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING'],
#  'A01B': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL '],
#  'A01C': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'PLANTING;SOWING;FERTILISING '],
#  'A01D': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'HARVESTING;MOWING'],
#  'A01F': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'PROCESSING OF HARVESTED PRODUCE;HAY OR STRAW PRESSES;DEVICES FOR STORING AGRICULTURAL OR HORTICULTURAL PRODUCE '],
#  'A01G': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'HORTICULTURE;CULTIVATION OF VEGETABLES, FLOWERS, RICE, FRUIT, VINES, HOPS OR SEAWEED;FORESTRY;WATERING '],
#  'A01H': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'NEW PLANTS OR ;PLANT REPRODUCTION BY TISSUE CULTURE TECHNIQUES;NON-TRANSGENIC'],
#  'A01J': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'MANUFACTURE OF DAIRY PRODUCTS '],
#  'A01K': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'ANIMAL HUSBANDRY;AVICULTURE;APICULTURE;PISCICULTURE;FISHING;REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR;NEW BREEDS OF ANIMALS'],
#  'A01L': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SHOEING OF ANIMALS'],
#  'A01M': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'CATCHING, TRAPPING OR SCARING OF ANIMALS ;APPARATUS FOR THE DESTRUCTION OF NOXIOUS ANIMALS OR NOXIOUS PLANTS'],
#  'A01N': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'PRESERVATION OF BODIES OF HUMANS OR ANIMALS OR PLANTS OR PARTS THEREOF ;BIOCIDES, e.g. AS DISINFECTANTS, AS PESTICIDES OR AS HERBICIDES ;PEST REPELLANTS OR ATTRACTANTS;PLANT GROWTH REGULATORS'],
#  'A01P': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'BIOCIDAL, PEST REPELLANT, PEST ATTRACTANT OR PLANT GROWTH REGULATORY ACTIVITY OF CHEMICAL COMPOUNDS OR PREPARATIONS'],
#  'A21': ['HUMAN NECESSITIES', 'FOODSTUFFS;TOBACCO', 'BAKING;EDIBLE DOUGHS'],
#  'A21B': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BAKING;EDIBLE DOUGHS',
#   "BAKERS' OVENS;MACHINES OR EQUIPMENT FOR BAKING "],
#  'A21C': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BAKING;EDIBLE DOUGHS',
#   'MACHINES OR EQUIPMENT FOR MAKING OR PROCESSING DOUGHS;HANDLING BAKED ARTICLES MADE FROM DOUGH'],
#  'A21D': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BAKING;EDIBLE DOUGHS',
#   'TREATMENT, e.g. PRESERVATION, OF FLOUR OR DOUGH, e.g. BY ADDITION OF MATERIALS;BAKING;BAKERY PRODUCTS;PRESERVATION THEREOF'],
#  'A22': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH'],
#  'A22B': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH',
#   'SLAUGHTERING'],
#  'A22C': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH',
#   'PROCESSING MEAT, POULTRY, OR FISH '],
#  'A23': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES'],
#  'A23B': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'PRESERVING, e.g. BY CANNING, MEAT, FISH, EGGS, FRUIT, VEGETABLES, EDIBLE SEEDS;CHEMICAL RIPENING OF FRUIT OR VEGETABLES;THE PRESERVED, RIPENED, OR CANNED PRODUCTS'],
#  'A23C': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'DAIRY PRODUCTS, e.g. MILK, BUTTER OR CHEESE;MILK OR CHEESE SUBSTITUTES;MAKING THEREOF '],
#  'A23D': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'EDIBLE OILS OR FATS, e.g. MARGARINES, SHORTENINGS, COOKING OILS '],
#  'A23F': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'COFFEE;TEA;THEIR SUBSTITUTES;MANUFACTURE, PREPARATION, OR INFUSION THEREOF'],
#  'A23G': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'COCOA;COCOA PRODUCTS, e.g. CHOCOLATE;SUBSTITUTES FOR COCOA OR COCOA PRODUCTS;CONFECTIONERY;CHEWING GUM;ICE-CREAM;PREPARATION THEREOF'],
#  'A23J': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'PROTEIN COMPOSITIONS FOR FOODSTUFFS;WORKING-UP PROTEINS FOR FOODSTUFFS;PHOSPHATIDE COMPOSITIONS FOR FOODSTUFFS'],
#  'A23K': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'FODDER'],
#  'A23L': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'FOODS, FOODSTUFFS, OR NON-ALCOHOLIC BEVERAGES, NOT COVERED BY SUBCLASSES ;THEIR PREPARATION OR TREATMENT, e.g. COOKING, MODIFICATION OF NUTRITIVE QUALITIES, PHYSICAL TREATMENT ;PRESERVATION OF FOODS OR FOODSTUFFS, IN GENERAL'],
#  'A23N': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'MACHINES OR APPARATUS FOR TREATING HARVESTED FRUIT, VEGETABLES OR FLOWER BULBS IN BULK, NOT OTHERWISE PROVIDED FOR;PEELING VEGETABLES OR FRUIT IN BULK;APPARATUS FOR PREPARING ANIMAL FEEDING- STUFFS '],
#  'A23P': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'SHAPING OR WORKING OF FOODSTUFFS, NOT FULLY COVERED BY A SINGLE OTHER SUBCLASS'],
#  'A23V': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   'FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#   'INDEXING SCHEME RELATING TO FOODS, FOODSTUFFS OR NON-ALCOHOLIC BEVERAGES AND LACTIC OR PROPIONIC ACID BACTERIA USED IN FOODSTUFFS OR FOOD PREPARATION'],
#  'A24': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   "TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES"],
#  'A24B': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   "TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES",
#   'MANUFACTURE OR PREPARATION OF TOBACCO FOR SMOKING OR CHEWING;TOBACCO;SNUFF'],
#  'A24C': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   "TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES",
#   'MACHINES FOR MAKING CIGARS OR CIGARETTES'],
#  'A24D': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   "TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES",
#   'CIGARS;CIGARETTES;TOBACCO SMOKE FILTERS;MOUTHPIECES FOR CIGARS OR CIGARETTES;MANUFACTURE OF TOBACCO SMOKE FILTERS OR MOUTHPIECES'],
#  'A24F': ['HUMAN NECESSITIES',
#   'FOODSTUFFS;TOBACCO',
#   "TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES",
#   "SMOKERS' REQUISITES;MATCH BOXES;SIMULATED SMOKING DEVICES "],
#  'A41': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL'],
#  'A41B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'SHIRTS;UNDERWEAR;BABY LINEN;HANDKERCHIEFS'],
#  'A41C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'CORSETS;BRASSIERES'],
#  'A41D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'OUTERWEAR;PROTECTIVE GARMENTS;ACCESSORIES'],
#  'A41F': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'GARMENT FASTENINGS;SUSPENDERS'],
#  'A41G': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'ARTIFICIAL FLOWERS;WIGS;MASKS;FEATHERS'],
#  'A41H': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'WEARING APPAREL',
#   'APPLIANCES OR METHODS FOR MAKING CLOTHES, e.g. FOR DRESS-MAKING OR FOR TAILORING, NOT OTHERWISE PROVIDED FOR'],
#  'A42': ['HUMAN NECESSITIES', 'PERSONAL OR DOMESTIC ARTICLES', 'HEADWEAR'],
#  'A42B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HEADWEAR',
#   'HATS;HEAD COVERINGS '],
#  'A42C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HEADWEAR',
#   'MANUFACTURING OR TRIMMING HEAD COVERINGS, e.g. HATS'],
#  'A43': ['HUMAN NECESSITIES', 'PERSONAL OR DOMESTIC ARTICLES', 'FOOTWEAR'],
#  'A43B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FOOTWEAR',
#   'CHARACTERISTIC FEATURES OF FOOTWEAR;PARTS OF FOOTWEAR'],
#  'A43C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FOOTWEAR',
#   'FASTENINGS OR ATTACHMENTS OF FOOTWEAR;LACES IN GENERAL'],
#  'A43D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FOOTWEAR',
#   'MACHINES, TOOLS, EQUIPMENT OR METHODS FOR MANUFACTURING OR REPAIRING FOOTWEAR'],
#  'A44': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HABERDASHERY;JEWELLERY'],
#  'A44B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HABERDASHERY;JEWELLERY',
#   'BUTTONS, PINS, BUCKLES, SLIDE FASTENERS, OR THE LIKE '],
#  'A44C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HABERDASHERY;JEWELLERY',
#   'PERSONAL ADORNMENTS, e.g. JEWELLERY;COINS'],
#  'A44D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HABERDASHERY;JEWELLERY',
#   'INDEXING SCHEME RELATING TO BUTTONS, PINS, BUCKLES OR SLIDE FASTENERS, AND TO JEWELLERY, BRACELETS OR OTHER PERSONAL ADORNMENTS'],
#  'A45': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HAND OR TRAVELLING ARTICLES'],
#  'A45B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HAND OR TRAVELLING ARTICLES',
#   "WALKING STICKS ;UMBRELLAS;LADIES' OR LIKE FANS "],
#  'A45C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HAND OR TRAVELLING ARTICLES',
#   'PURSES;LUGGAGE;HAND CARRIED BAGS'],
#  'A45D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HAND OR TRAVELLING ARTICLES',
#   'HAIRDRESSING OR SHAVING EQUIPMENT ;EQUIPMENT FOR COSMETICS OR COSMETIC TREATMENTS, e.g. FOR MANICURING OR PEDICURING'],
#  'A45F': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'HAND OR TRAVELLING ARTICLES',
#   'TRAVELLING OR CAMP EQUIPMENT: SACKS OR PACKS CARRIED ON THE BODY'],
#  'A46': ['HUMAN NECESSITIES', 'PERSONAL OR DOMESTIC ARTICLES', 'BRUSHWARE'],
#  'A46B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'BRUSHWARE',
#   'BRUSHES '],
#  'A46D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'BRUSHWARE',
#   'MANUFACTURE OF BRUSHES'],
#  'A47': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL'],
#  'A47B': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'TABLES;DESKS;OFFICE FURNITURE;CABINETS;DRAWERS;GENERAL DETAILS OF FURNITURE '],
#  'A47C': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'CHAIRS ;SOFAS;BEDS '],
#  'A47D': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'FURNITURE SPECIALLY ADAPTED FOR CHILDREN '],
#  'A47F': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'SPECIAL FURNITURE, FITTINGS, OR ACCESSORIES FOR SHOPS, STOREHOUSES, BARS, RESTAURANTS OR THE LIKE;PAYING COUNTERS'],
#  'A47G': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'HOUSEHOLD OR TABLE EQUIPMENT '],
#  'A47H': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'FURNISHINGS FOR WINDOWS OR DOORS '],
#  'A47J': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'KITCHEN EQUIPMENT;COFFEE MILLS;SPICE MILLS;APPARATUS FOR MAKING BEVERAGES'],
#  'A47K': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'SANITARY EQUIPMENT NOT OTHERWISE PROVIDED FOR ;TOILET ACCESSORIES '],
#  'A47L': ['HUMAN NECESSITIES',
#   'PERSONAL OR DOMESTIC ARTICLES',
#   'FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#   'DOMESTIC WASHING OR CLEANING ;SUCTION CLEANERS IN GENERAL '],
#  'A61': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE'],
#  'A61B': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'DIAGNOSIS;SURGERY;IDENTIFICATION '],
#  'A61C': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'DENTISTRY;APPARATUS OR METHODS FOR ORAL OR DENTAL HYGIENE '],
#  'A61D': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'VETERINARY INSTRUMENTS, IMPLEMENTS, TOOLS, OR METHODS'],
#  'A61F': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'FILTERS IMPLANTABLE INTO BLOOD VESSELS;PROSTHESES;DEVICES PROVIDING PATENCY TO, OR PREVENTING COLLAPSING OF, TUBULAR STRUCTURES OF THE BODY, e.g. STENTS;ORTHOPAEDIC, NURSING OR CONTRACEPTIVE DEVICES;FOMENTATION;TREATMENT OR PROTECTION OF EYES OR EARS;BANDAGES, DRESSINGS OR ABSORBENT PADS;FIRST-AID KITS '],
#  'A61G': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'TRANSPORT, PERSONAL CONVEYANCES, OR ACCOMMODATION SPECIALLY ADAPTED FOR PATIENTS OR DISABLED PERSONS ;OPERATING TABLES OR CHAIRS;CHAIRS FOR DENTISTRY;FUNERAL DEVICES '],
#  'A61H': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'PHYSICAL THERAPY APPARATUS, e.g. DEVICES FOR LOCATING OR STIMULATING REFLEX POINTS IN THE BODY;ARTIFICIAL RESPIRATION;MASSAGE;BATHING DEVICES FOR SPECIAL THERAPEUTIC OR HYGIENIC PURPOSES OR SPECIFIC PARTS OF THE BODY '],
#  'A61J': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'CONTAINERS SPECIALLY ADAPTED FOR MEDICAL OR PHARMACEUTICAL PURPOSES;DEVICES OR METHODS SPECIALLY ADAPTED FOR BRINGING PHARMACEUTICAL PRODUCTS INTO PARTICULAR PHYSICAL OR ADMINISTERING FORMS;DEVICES FOR ADMINISTERING FOOD OR MEDICINES ORALLY;BABY COMFORTERS;DEVICES FOR RECEIVING SPITTLE'],
#  'A61K': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'PREPARATIONS FOR MEDICAL, DENTAL OR TOILETRY PURPOSES '],
#  'A61L': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'METHODS OR APPARATUS FOR STERILISING MATERIALS OR OBJECTS IN GENERAL;DISINFECTION, STERILISATION OR DEODORISATION OF AIR;CHEMICAL ASPECTS OF BANDAGES, DRESSINGS, ABSORBENT PADS OR SURGICAL ARTICLES;MATERIALS FOR BANDAGES, DRESSINGS, ABSORBENT PADS OR SURGICAL ARTICLES '],
#  'A61M': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'DEVICES FOR INTRODUCING MEDIA INTO, OR ONTO, THE BODY ;DEVICES FOR TRANSDUCING BODY MEDIA OR FOR TAKING MEDIA FROM THE BODY ;DEVICES FOR PRODUCING OR ENDING SLEEP OR STUPOR '],
#  'A61N': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'ELECTROTHERAPY;MAGNETOTHERAPY;RADIATION THERAPY;ULTRASOUND THERAPY '],
#  'A61P': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'SPECIFIC THERAPEUTIC ACTIVITY OF CHEMICAL COMPOUNDS OR MEDICINAL PREPARATIONS'],
#  'A61Q': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#   'SPECIFIC USE OF COSMETICS OR SIMILAR TOILETRY PREPARATIONS'],
#  'A62': ['HUMAN NECESSITIES', 'HEALTH;AMUSEMENT', 'LIFE-SAVING;FIRE-FIGHTING'],
#  'A62B': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'LIFE-SAVING;FIRE-FIGHTING',
#   'DEVICES, APPARATUS OR METHODS FOR LIFE-SAVING '],
#  'A62C': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'LIFE-SAVING;FIRE-FIGHTING',
#   'FIRE-FIGHTING '],
#  'A62D': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'LIFE-SAVING;FIRE-FIGHTING',
#   'CHEMICAL MEANS FOR EXTINGUISHING FIRES OR FOR COMBATING OR PROTECTING AGAINST HARMFUL CHEMICAL AGENTS;CHEMICAL MATERIALS FOR USE IN BREATHING APPARATUS'],
#  'A63': ['HUMAN NECESSITIES', 'HEALTH;AMUSEMENT', 'SPORTS;GAMES;AMUSEMENTS'],
#  'A63B': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'APPARATUS FOR PHYSICAL TRAINING, GYMNASTICS, SWIMMING, CLIMBING, OR FENCING;BALL GAMES;TRAINING EQUIPMENT '],
#  'A63C': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'SKATES;SKIS;ROLLER SKATES;DESIGN OR LAYOUT OF COURTS, RINKS OR THE LIKE '],
#  'A63D': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'BOWLING GAMES, e.g. SKITTLES, BOCCE OR BOWLS;INSTALLATIONS THEREFOR;BAGATELLE OR SIMILAR GAMES;BILLIARDS '],
#  'A63F': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'CARD, BOARD, OR ROULETTE GAMES;INDOOR GAMES USING SMALL MOVING PLAYING BODIES;VIDEO GAMES;GAMES NOT OTHERWISE PROVIDED FOR'],
#  'A63G': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'MERRY-GO-ROUNDS;SWINGS;ROCKING-HORSES;CHUTES;SWITCHBACKS;SIMILAR DEVICES FOR PUBLIC AMUSEMENT'],
#  'A63H': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'TOYS, e.g. TOPS, DOLLS, HOOPS OR BUILDING BLOCKS'],
#  'A63J': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'DEVICES FOR THEATRES, CIRCUSES, OR THE LIKE;CONJURING APPLIANCES OR THE LIKE'],
#  'A63K': ['HUMAN NECESSITIES',
#   'HEALTH;AMUSEMENT',
#   'SPORTS;GAMES;AMUSEMENTS',
#   'RACING;RIDING SPORTS;EQUIPMENT OR ACCESSORIES THEREFOR '],
#  'A99': ['HUMAN NECESSITIES',
#   '',
#   'SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION'],
#  'A99Z': ['HUMAN NECESSITIES',
#   '',
#   'SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION',
#   'SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION'],
#  'B': ['PERFORMING OPERATIONS;TRANSPORTING'],
#  'B01': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL'],
#  'B01B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#   'BOILING;BOILING APPARATUS ;; EVAPORATION; EVAPORATION APPARATUS'],
#  'B01D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#   'SEPARATION '],
#  'B01F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#   'MIXING, e.g. DISSOLVING, EMULSIFYING OR DISPERSING '],
#  'B01J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#   'CHEMICAL OR PHYSICAL PROCESSES, e.g. CATALYSIS OR COLLOID CHEMISTRY;THEIR RELEVANT APPARATUS'],
#  'B01L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#   'CHEMICAL OR PHYSICAL LABORATORY APPARATUS FOR GENERAL USE'],
#  'B02': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING'],
#  'B02B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING',
#   'PREPARING GRAIN FOR MILLING;REFINING GRANULAR FRUIT TO COMMERCIAL PRODUCTS BY WORKING THE SURFACE '],
#  'B02C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING',
#   'CRUSHING, PULVERISING, OR DISINTEGRATING IN GENERAL;MILLING GRAIN '],
#  'B03': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS'],
#  'B03B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS',
#   'SEPARATING SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS'],
#  'B03C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS',
#   'MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS '],
#  'B03D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS',
#   'FLOTATION;DIFFERENTIAL SEDIMENTATION '],
#  'B04': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES'],
#  'B04B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES',
#   'CENTRIFUGES '],
#  'B04C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES',
#   'APPARATUS USING FREE VORTEX FLOW, e.g. CYCLONES '],
#  'B05': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL'],
#  'B05B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL',
#   'SPRAYING APPARATUS;ATOMISING APPARATUS;NOZZLES '],
#  'B05C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL',
#   'APPARATUS FOR APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL '],
#  'B05D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL',
#   'PROCESSES FOR APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL '],
#  'B06': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS IN GENERAL'],
#  'B06B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS IN GENERAL',
#   'METHODS OR APPARATUS FOR GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS OF INFRASONIC, SONIC, OR ULTRASONIC FREQUENCY, ;e.g.'],
#  'B07': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATING SOLIDS FROM SOLIDS;SORTING'],
#  'B07B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATING SOLIDS FROM SOLIDS;SORTING',
#   'SEPARATING SOLIDS FROM SOLIDS BY SIEVING, SCREENING, SIFTING OR BY USING GAS CURRENTS;SEPARATING BY OTHER DRY METHODS APPLICABLE TO BULK MATERIAL, e.g. LOOSE ARTICLES FIT TO BE HANDLED LIKE BULK MATERIAL '],
#  'B07C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'SEPARATING SOLIDS FROM SOLIDS;SORTING',
#   'POSTAL SORTING;SORTING INDIVIDUAL ARTICLES, OR BULK MATERIAL FIT TO BE SORTED PIECE-MEAL, e.g. BY PICKING '],
#  'B08': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CLEANING'],
#  'B08B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'CLEANING',
#   'CLEANING IN GENERAL;PREVENTION OF FOULING IN GENERAL '],
#  'B09': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL'],
#  'B09B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL',
#   'DISPOSAL OF SOLID WASTE NOT OTHERWISE PROVIDED FOR'],
#  'B09C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SEPARATING;MIXING',
#   'DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL',
#   'RECLAMATION OF CONTAMINATED SOIL '],
#  'B21': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL'],
#  'B21B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'ROLLING OF METAL '],
#  'B21C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'MANUFACTURE OF METAL SHEETS, WIRE, RODS, TUBES OR PROFILES, OTHERWISE THAN BY ROLLING;AUXILIARY OPERATIONS USED IN CONNECTION WITH METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL'],
#  'B21D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'WORKING OR PROCESSING OF SHEET METAL OR METAL TUBES, RODS OR PROFILES WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL '],
#  'B21F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'WORKING OR PROCESSING OF METAL WIRE '],
#  'B21G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'MAKING NEEDLES, PINS OR NAILS OF METAL'],
#  'B21H': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'MAKING PARTICULAR METAL OBJECTS BY ROLLING, e.g. SCREWS, WHEELS, RINGS, BARRELS, BALLS '],
#  'B21J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'FORGING;HAMMERING;PRESSING METAL;RIVETING;FORGE FURNACES '],
#  'B21K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'MAKING FORGED OR PRESSED METAL PRODUCTS, e.g. HORSE-SHOES, RIVETS, BOLTS OR WHEELS '],
#  'B21L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#   'MAKING METAL CHAINS '],
#  'B22': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'CASTING;POWDER METALLURGY'],
#  'B22C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'CASTING;POWDER METALLURGY',
#   'FOUNDRY MOULDING '],
#  'B22D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'CASTING;POWDER METALLURGY',
#   'CASTING OF METALS;CASTING OF OTHER SUBSTANCES BY THE SAME PROCESSES OR DEVICES '],
#  'B22F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'CASTING;POWDER METALLURGY',
#   'WORKING METALLIC POWDER;MANUFACTURE OF ARTICLES FROM METALLIC POWDER;MAKING METALLIC POWDER ;APPARATUS OR DEVICES SPECIALLY ADAPTED FOR METALLIC POWDER'],
#  'B23': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR'],
#  'B23B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'TURNING;BORING '],
#  'B23C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'MILLING '],
#  'B23D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'PLANING;SLOTTING;SHEARING;BROACHING;SAWING;FILING;SCRAPING;LIKE OPERATIONS FOR WORKING METAL BY REMOVING MATERIAL, NOT OTHERWISE PROVIDED FOR '],
#  'B23F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'MAKING GEARS OR TOOTHED RACKS '],
#  'B23G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'THREAD CUTTING;WORKING OF SCREWS, BOLT HEADS, OR NUTS, IN CONJUNCTION THEREWITH '],
#  'B23H': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'WORKING OF METAL BY THE ACTION OF A HIGH CONCENTRATION OF ELECTRIC CURRENT ON A WORKPIECE USING AN ELECTRODE WHICH TAKES THE PLACE OF A TOOL;SUCH WORKING COMBINED WITH OTHER FORMS OF WORKING OF METAL '],
#  'B23K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'SOLDERING OR UNSOLDERING;WELDING;CLADDING OR PLATING BY SOLDERING OR WELDING;CUTTING BY APPLYING HEAT LOCALLY, e.g. FLAME CUTTING;WORKING BY LASER BEAM '],
#  'B23P': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'METAL-WORKING NOT OTHERWISE PROVIDED FOR;COMBINED OPERATIONS;UNIVERSAL MACHINE TOOLS '],
#  'B23Q': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#   'DETAILS, COMPONENTS, OR ACCESSORIES FOR MACHINE TOOLS, e.g. ARRANGEMENTS FOR COPYING OR CONTROLLING ;MACHINE TOOLS IN GENERAL CHARACTERISED BY THE CONSTRUCTION OF PARTICULAR DETAILS OR COMPONENTS;COMBINATIONS OR ASSOCIATIONS OF METAL-WORKING MACHINES, NOT DIRECTED TO A PARTICULAR RESULT'],
#  'B24': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'GRINDING;POLISHING'],
#  'B24B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'GRINDING;POLISHING',
#   'MACHINES, DEVICES, OR PROCESSES FOR GRINDING OR POLISHING ;DRESSING OR CONDITIONING OF ABRADING SURFACES;FEEDING OF GRINDING, POLISHING, OR LAPPING AGENTS'],
#  'B24C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'GRINDING;POLISHING',
#   'ABRASIVE OR RELATED BLASTING WITH PARTICULATE MATERIAL'],
#  'B24D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'GRINDING;POLISHING',
#   'TOOLS FOR GRINDING, BUFFING OR SHARPENING '],
#  'B25': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS'],
#  'B25B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'TOOLS OR BENCH DEVICES NOT OTHERWISE PROVIDED FOR, FOR FASTENING, CONNECTING, DISENGAGING OR HOLDING'],
#  'B25C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'HAND-HELD NAILING OR STAPLING TOOLS;MANUALLY OPERATED PORTABLE STAPLING TOOLS '],
#  'B25D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'PERCUSSIVE TOOLS '],
#  'B25F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'COMBINATION OR MULTI-PURPOSE TOOLS NOT OTHERWISE PROVIDED FOR;DETAILS OR COMPONENTS OF PORTABLE POWER-DRIVEN TOOLS NOT PARTICULARLY RELATED TO THE OPERATIONS PERFORMED AND NOT OTHERWISE PROVIDED FOR '],
#  'B25G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'HANDLES FOR HAND IMPLEMENTS '],
#  'B25H': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'WORKSHOP EQUIPMENT, e.g. FOR MARKING-OUT WORK;STORAGE MEANS FOR WORKSHOPS '],
#  'B25J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#   'MANIPULATORS;CHAMBERS PROVIDED WITH MANIPULATION DEVICES '],
#  'B26': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND CUTTING TOOLS;CUTTING;SEVERING'],
#  'B26B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND CUTTING TOOLS;CUTTING;SEVERING',
#   'HAND-HELD CUTTING TOOLS NOT OTHERWISE PROVIDED FOR '],
#  'B26D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND CUTTING TOOLS;CUTTING;SEVERING',
#   'CUTTING;DETAILS COMMON TO MACHINES FOR PERFORATING, PUNCHING, CUTTING-OUT, STAMPING-OUT OR SEVERING '],
#  'B26F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'HAND CUTTING TOOLS;CUTTING;SEVERING',
#   'PERFORATING;PUNCHING;CUTTING-OUT;STAMPING-OUT;SEVERING BY MEANS OTHER THAN CUTTING '],
#  'B27': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL'],
#  'B27B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'SAWS FOR WOOD OR SIMILAR MATERIAL;COMPONENTS OR ACCESSORIES THEREFOR '],
#  'B27C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'PLANING, DRILLING, MILLING, TURNING OR UNIVERSAL MACHINES FOR WOOD OR SIMILAR MATERIAL '],
#  'B27D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'WORKING VENEER OR PLYWOOD '],
#  'B27F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'DOVETAILED WORK;TENONS;SLOTTING MACHINES FOR WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES '],
#  'B27G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'ACCESSORY MACHINES OR APPARATUS FOR WORKING WOOD OR SIMILAR MATERIALS;TOOLS FOR WORKING WOOD OR SIMILAR MATERIALS ;SAFETY DEVICES FOR WOOD WORKING MACHINES OR TOOLS'],
#  'B27H': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'BENDING WOOD OR SIMILAR MATERIAL;COOPERAGE;MAKING WHEELS FROM WOOD OR SIMILAR MATERIAL'],
#  'B27J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'MECHANICAL WORKING OF CANE, CORK, OR SIMILAR MATERIALS'],
#  'B27K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'PROCESSES, APPARATUS OR SELECTION OF SUBSTANCES FOR IMPREGNATING, STAINING, DYEING, BLEACHING OF WOOD OR SIMILAR MATERIALS, OR TREATING OF WOOD OR SIMILAR MATERIALS WITH PERMEANT LIQUIDS, NOT OTHERWISE PROVIDED FOR ;CHEMICAL OR PHYSICAL TREATMENT OF CORK, CANE, REED, STRAW OR SIMILAR MATERIALS'],
#  'B27L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'REMOVING BARK OR VESTIGES OF BRANCHES ;SPLITTING WOOD;MANUFACTURE OF VENEER, WOODEN STICKS, WOOD SHAVINGS, WOOD FIBRES OR WOOD POWDER'],
#  'B27M': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'WORKING OF WOOD NOT PROVIDED FOR IN SUBCLASSES ;MANUFACTURE OF SPECIFIC WOODEN ARTICLES'],
#  'B27N': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#   'MANUFACTURE BY DRY PROCESSES OF ARTICLES, WITH OR WITHOUT ORGANIC BINDING AGENTS, MADE FROM PARTICLES OR FIBRES CONSISTING OF WOOD OR OTHER LIGNOCELLULOSIC OR LIKE ORGANIC MATERIAL '],
#  'B28': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING CEMENT, CLAY, OR STONE'],
#  'B28B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING CEMENT, CLAY, OR STONE',
#   'SHAPING CLAY OR OTHER CERAMIC COMPOSITIONS;SHAPING SLAG;SHAPING MIXTURES CONTAINING CEMENTITIOUS MATERIAL, e.g. PLASTER '],
#  'B28C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING CEMENT, CLAY, OR STONE',
#   'PREPARING CLAY;PRODUCING MIXTURES CONTAINING CLAY OR CEMENTITIOUS MATERIAL, e.g. PLASTER '],
#  'B28D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING CEMENT, CLAY, OR STONE',
#   'WORKING STONE OR STONE-LIKE MATERIALS'],
#  'B29': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL'],
#  'B29B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#   'PREPARATION OR PRETREATMENT OF THE MATERIAL TO BE SHAPED;MAKING GRANULES OR PREFORMS;RECOVERY OF PLASTICS OR OTHER CONSTITUENTS OF WASTE MATERIAL CONTAINING PLASTICS'],
#  'B29C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#   'SHAPING OR JOINING OF PLASTICS;SHAPING OF MATERIAL IN A PLASTIC STATE, NOT OTHERWISE PROVIDED FOR;AFTER-TREATMENT OF THE SHAPED PRODUCTS, e.g. REPAIRING '],
#  'B29D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#   'PRODUCING PARTICULAR ARTICLES FROM PLASTICS OR FROM SUBSTANCES IN A PLASTIC STATE '],
#  'B29K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#   'INDEXING SCHEME ASSOCIATED WITH SUBCLASSES ;MOULDS, '],
#  'B29L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#   'INDEXING SCHEME ASSOCIATED WITH SUBCLASS '],
#  'B30': ['PERFORMING OPERATIONS;TRANSPORTING', 'SHAPING', 'PRESSES'],
#  'B30B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'PRESSES',
#   'PRESSES IN GENERAL '],
#  'B31': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER'],
#  'B31B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#   'MAKING CONTAINERS OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER '],
#  'B31C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#   'MAKING WOUND ARTICLES, e.g. WOUND TUBES, OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER'],
#  'B31D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER, NOT PROVIDED FOR IN SUBCLASSES '],
#  'B31F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#   'MECHANICAL WORKING OR DEFORMATION OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER '],
#  'B32': ['PERFORMING OPERATIONS;TRANSPORTING', 'SHAPING', 'LAYERED PRODUCTS'],
#  'B32B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'LAYERED PRODUCTS',
#   'LAYERED PRODUCTS, i.e. PRODUCTS BUILT-UP OF STRATA OF FLAT OR NON-FLAT, e.g. CELLULAR OR HONEYCOMB, FORM'],
#  'B33': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'ADDITIVE MANUFACTURING TECHNOLOGY'],
#  'B33Y': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'SHAPING',
#   'ADDITIVE MANUFACTURING TECHNOLOGY',
#   'ADDITIVE MANUFACTURING, i.e. MANUFACTURING OF THREE-DIMENSIONAL [3-D] OBJECTS BY ADDITIVE DEPOSITION, ADDITIVE AGGLOMERATION OR ADDITIVE LAYERING, e.g. BY 3-D PRINTING, STEREOLITHOGRAPHY OR SELECTIVE LASER SINTERING'],
#  'B41': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS'],
#  'B41B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'MACHINES OR ACCESSORIES FOR MAKING, SETTING, OR DISTRIBUTING TYPE;TYPE;PHOTOGRAPHIC OR PHOTOELECTRIC COMPOSING DEVICES '],
#  'B41C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'PROCESSES FOR THE MANUFACTURE OR REPRODUCTION OF PRINTING SURFACES '],
#  'B41D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'APPARATUS FOR THE MECHANICAL REPRODUCTION OF PRINTING SURFACES FOR STEREOTYPE PRINTING;SHAPING ELASTIC OR DEFORMABLE MATERIAL TO FORM PRINTING SURFACES '],
#  'B41F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'PRINTING MACHINES OR PRESSES '],
#  'B41G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'APPARATUS FOR BRONZE PRINTING, LINE PRINTING, OR FOR BORDERING OR EDGING SHEETS OR LIKE ARTICLES;AUXILIARY FOR PERFORATING IN CONJUNCTION WITH PRINTING '],
#  'B41J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'TYPEWRITERS;SELECTIVE PRINTING MECHANISMS, i.e. MECHANISMS PRINTING OTHERWISE THAN FROM A FORME;CORRECTION OF TYPOGRAPHICAL ERRORS'],
#  'B41K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'STAMPS;STAMPING OR NUMBERING APPARATUS OR DEVICES '],
#  'B41L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'APPARATUS OR DEVICES FOR MANIFOLDING, DUPLICATING OR PRINTING FOR OFFICE OR OTHER COMMERCIAL PURPOSES;ADDRESSING MACHINES OR LIKE SERIES-PRINTING MACHINES '],
#  'B41M': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'PRINTING, DUPLICATING, MARKING, OR COPYING PROCESSES;COLOUR PRINTING, '],
#  'B41N': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'PRINTING PLATES OR FOILS ;MATERIALS FOR SURFACES USED IN PRINTING MACHINES FOR PRINTING, INKING, DAMPING, OR THE LIKE;PREPARING SUCH SURFACES FOR USE AND CONSERVING THEM'],
#  'B41P': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#   'INDEXING SCHEME RELATING TO PRINTING, LINING MACHINES, TYPEWRITERS, AND TO STAMPS'],
#  'B42': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER'],
#  'B42B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#   'PERMANENTLY ATTACHING TOGETHER SHEETS, QUIRES OR SIGNATURES OR PERMANENTLY ATTACHING OBJECTS THERETO '],
#  'B42C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#   'BOOKBINDING '],
#  'B42D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#   'BOOKS;BOOK COVERS;LOOSE LEAVES;PRINTED MATTER CHARACTERISED BY IDENTIFICATION OR SECURITY FEATURES; PRINTED MATTER OF SPECIAL FORMAT OR STYLE NOT OTHERWISE PROVIDED FOR;DEVICES FOR USE THEREWITH AND NOT OTHERWISE PROVIDED FOR;MOVABLE-STRIP WRITING OR READING APPARATUS'],
#  'B42F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#   'SHEETS TEMPORARILY ATTACHED TOGETHER;FILING APPLIANCES;FILE CARDS;INDEXING '],
#  'B42P': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#   'INDEXING SCHEME RELATING TO BOOKS, FILING APPLIANCES OR THE LIKE'],
#  'B43': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES'],
#  'B43K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES',
#   'IMPLEMENTS FOR WRITING OR DRAWING '],
#  'B43L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES',
#   'ARTICLES FOR WRITING OR DRAWING UPON; ;WRITING OR DRAWING AIDS;'],
#  'B43M': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES',
#   'BUREAU ACCESSORIES NOT OTHERWISE PROVIDED FOR '],
#  'B44': ['PERFORMING OPERATIONS;TRANSPORTING', 'PRINTING', 'DECORATIVE ARTS'],
#  'B44B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'DECORATIVE ARTS',
#   'MACHINES, APPARATUS OR TOOLS FOR ARTISTIC WORK, e.g. FOR SCULPTURING, GUILLOCHING, CARVING, BRANDING, INLAYING '],
#  'B44C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'DECORATIVE ARTS',
#   'PRODUCING DECORATIVE EFFECTS ;MOSAICS;TARSIA WORK ;PAPERHANGING '],
#  'B44D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'DECORATIVE ARTS',
#   'PAINTING OR ARTISTIC DRAWING, NOT OTHERWISE PROVIDED FOR;PRESERVING PAINTINGS;SURFACE TREATMENT TO OBTAIN SPECIAL ARTISTIC SURFACE EFFECTS OR FINISHES '],
#  'B44F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'PRINTING',
#   'DECORATIVE ARTS',
#   'SPECIAL DESIGNS OR PICTURES'],
#  'B60': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL'],
#  'B60B': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'VEHICLE WHEELS ;CASTORS;AXLES FOR WHEELS OR CASTORS;INCREASING WHEEL ADHESION'],
#  'B60C': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'VEHICLE TYRES;TYRE INFLATION;TYRE CHANGING;CONNECTING VALVES TO INFLATABLE ELASTIC BODIES IN GENERAL;DEVICES OR ARRANGEMENTS RELATED TO TYRES'],
#  'B60D': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'VEHICLE CONNECTIONS '],
#  'B60F': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'VEHICLES FOR USE BOTH ON RAIL AND ON ROAD;AMPHIBIOUS OR LIKE VEHICLES;CONVERTIBLE VEHICLES '],
#  'B60G': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'VEHICLE SUSPENSION ARRANGEMENTS '],
#  'B60H': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'ARRANGEMENTS OF HEATING, COOLING, VENTILATING OR OTHER AIR-TREATING DEVICES SPECIALLY ADAPTED FOR PASSENGER OR GOODS SPACES OF VEHICLES'],
#  'B60J': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'WINDOWS, WINDSCREENS, NON-FIXED ROOFS, DOORS, OR SIMILAR DEVICES FOR VEHICLES;REMOVABLE EXTERNAL PROTECTIVE COVERINGS SPECIALLY ADAPTED FOR VEHICLES '],
#  'B60K': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
#   'ARRANGEMENT OR MOUNTING OF PROPULSION UNITS OR OF TRANSMISSIONS IN VEHICLES;ARRANGEMENT OR MOUNTING OF PLURAL DIVERSE PRIME-MOVERS IN VEHICLES;AUXILIARY DRIVES FOR VEHICLES;INSTRUMENTATION OR DASHBOARDS FOR VEHICLES;ARRANGEMENTS IN CONNECTION WITH COOLING, AIR INTAKE, GAS EXHAUST OR FUEL SUPPLY OF PROPULSION UNITS IN VEHICLES'],
#  'B60L': ['PERFORMING OPERATIONS;TRANSPORTING',
#   'TRANSPORTING',
#   'VEHICLES IN GENERAL',
# ...
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with tools on horizontal shaft transverse to direction of travel',
#   'Operator supported tools, e.g. using a harness for supporting the tool or power unit'],
#  'A01B33/028': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with tools on horizontal shaft transverse to direction of travel',
#   'of the walk-behind type '],
#  'A01B33/04': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with tools on horizontal shaft parallel to direction of travel'],
#  'A01B33/06': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with tools on vertical or steeply-inclined shaft'],
#  'A01B33/065': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with tools on vertical or steeply-inclined shaft',
#   'comprising a plurality of rotors carried by an elongate, substantially closed transmission casing, transversely connectable to a tractor'],
#  'A01B33/08': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings'],
#  'A01B33/082': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Transmissions; Gearings; Power distribution'],
#  'A01B33/085': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Transmissions; Gearings; Power distribution',
#   'specially adapted for tools on a vertical shaft'],
#  'A01B33/087': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Lifting devices; Depth regulation devices; Mountings'],
#  'A01B33/10': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Structural or functional features of the tools ;; Theoretical aspects of the cutting action'],
#  'A01B33/103': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Structural or functional features of the tools ;; Theoretical aspects of the cutting action',
#   'the rotating shaft being oriented horizontally'],
#  'A01B33/106': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Structural or functional features of the tools ;; Theoretical aspects of the cutting action',
#   'the rotating shaft being oriented vertically or steeply inclined'],
#  'A01B33/12': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Arrangement of the tools;Screening of the tools'],
#  'A01B33/125': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Arrangement of the tools;Screening of the tools',
#   'screening of tools rotating about a vertical shaft'],
#  'A01B33/14': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly'],
#  'A01B33/142': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly',
#   'the rotating shaft being oriented horizontally'],
#  'A01B33/144': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly',
#   'the rotating shaft being oriented horizontally',
#   'with spring tools or resiliently-attached rigid tools'],
#  'A01B33/146': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly',
#   'the rotating shaft being oriented vertically or steeply inclined'],
#  'A01B33/148': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'Tools;Details, e.g. adaptations of transmissions or gearings',
#   'Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly',
#   'the rotating shaft being oriented vertically or steeply inclined',
#   'with spring tools or resiliently-attached rigid tools'],
#  'A01B33/16': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs',
#   'with special additional arrangements '],
#  'A01B35/00': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing'],
#  'A01B35/02': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools'],
#  'A01B35/04': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'drawn by animal or tractor ;or man-power'],
#  'A01B35/06': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'drawn by animal or tractor ;or man-power',
#   'with spring tools ;or with resiliently- or flexibly-attached rigid tools'],
#  'A01B35/08': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'drawn by animal or tractor ;or man-power',
#   'with rigid tools'],
#  'A01B35/10': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'mounted on tractors'],
#  'A01B35/12': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'mounted on tractors',
#   'with spring tools ;or with resiliently-or flexibly-attached rigid tools'],
#  'A01B35/14': ['HUMAN NECESSITIES',
#   'AGRICULTURE',
#   'AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#   'SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#   'Other machines for working soil',
#   'Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#   'with non-rotating tools',
#   'mounted on tractors',
#   'with rigid tools'],
#  ...}

# %%
for key, value_list in withSlashDict.items():
    filtered_list = [value for value in value_list if value != '']
    withSlashDict[key] = filtered_list

# %%
import re
withoutSlashDict={}
for key,val in withSlashDict.items():
    new_key=re.sub(r'[^a-zA-Z0-9]','',key)
    withoutSlashDict[new_key]='/ '.join(val)

# %%
withoutSlashDict
# Out:
# {'A': 'HUMAN NECESSITIES',
#  'A01': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING',
#  'A01B': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL ',
#  'A01C': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ PLANTING;SOWING;FERTILISING ',
#  'A01D': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ HARVESTING;MOWING',
#  'A01F': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ PROCESSING OF HARVESTED PRODUCE;HAY OR STRAW PRESSES;DEVICES FOR STORING AGRICULTURAL OR HORTICULTURAL PRODUCE ',
#  'A01G': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ HORTICULTURE;CULTIVATION OF VEGETABLES, FLOWERS, RICE, FRUIT, VINES, HOPS OR SEAWEED;FORESTRY;WATERING ',
#  'A01H': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ NEW PLANTS OR ;PLANT REPRODUCTION BY TISSUE CULTURE TECHNIQUES;NON-TRANSGENIC',
#  'A01J': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ MANUFACTURE OF DAIRY PRODUCTS ',
#  'A01K': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ ANIMAL HUSBANDRY;AVICULTURE;APICULTURE;PISCICULTURE;FISHING;REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR;NEW BREEDS OF ANIMALS',
#  'A01L': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SHOEING OF ANIMALS',
#  'A01M': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ CATCHING, TRAPPING OR SCARING OF ANIMALS ;APPARATUS FOR THE DESTRUCTION OF NOXIOUS ANIMALS OR NOXIOUS PLANTS',
#  'A01N': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ PRESERVATION OF BODIES OF HUMANS OR ANIMALS OR PLANTS OR PARTS THEREOF ;BIOCIDES, e.g. AS DISINFECTANTS, AS PESTICIDES OR AS HERBICIDES ;PEST REPELLANTS OR ATTRACTANTS;PLANT GROWTH REGULATORS',
#  'A01P': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ BIOCIDAL, PEST REPELLANT, PEST ATTRACTANT OR PLANT GROWTH REGULATORY ACTIVITY OF CHEMICAL COMPOUNDS OR PREPARATIONS',
#  'A21': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BAKING;EDIBLE DOUGHS',
#  'A21B': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BAKING;EDIBLE DOUGHS/ BAKERS' OVENS;MACHINES OR EQUIPMENT FOR BAKING ",
#  'A21C': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BAKING;EDIBLE DOUGHS/ MACHINES OR EQUIPMENT FOR MAKING OR PROCESSING DOUGHS;HANDLING BAKED ARTICLES MADE FROM DOUGH',
#  'A21D': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BAKING;EDIBLE DOUGHS/ TREATMENT, e.g. PRESERVATION, OF FLOUR OR DOUGH, e.g. BY ADDITION OF MATERIALS;BAKING;BAKERY PRODUCTS;PRESERVATION THEREOF',
#  'A22': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH',
#  'A22B': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH/ SLAUGHTERING',
#  'A22C': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ BUTCHERING;MEAT TREATMENT;PROCESSING POULTRY OR FISH/ PROCESSING MEAT, POULTRY, OR FISH ',
#  'A23': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES',
#  'A23B': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ PRESERVING, e.g. BY CANNING, MEAT, FISH, EGGS, FRUIT, VEGETABLES, EDIBLE SEEDS;CHEMICAL RIPENING OF FRUIT OR VEGETABLES;THE PRESERVED, RIPENED, OR CANNED PRODUCTS',
#  'A23C': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ DAIRY PRODUCTS, e.g. MILK, BUTTER OR CHEESE;MILK OR CHEESE SUBSTITUTES;MAKING THEREOF ',
#  'A23D': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ EDIBLE OILS OR FATS, e.g. MARGARINES, SHORTENINGS, COOKING OILS ',
#  'A23F': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ COFFEE;TEA;THEIR SUBSTITUTES;MANUFACTURE, PREPARATION, OR INFUSION THEREOF',
#  'A23G': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ COCOA;COCOA PRODUCTS, e.g. CHOCOLATE;SUBSTITUTES FOR COCOA OR COCOA PRODUCTS;CONFECTIONERY;CHEWING GUM;ICE-CREAM;PREPARATION THEREOF',
#  'A23J': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ PROTEIN COMPOSITIONS FOR FOODSTUFFS;WORKING-UP PROTEINS FOR FOODSTUFFS;PHOSPHATIDE COMPOSITIONS FOR FOODSTUFFS',
#  'A23K': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ FODDER',
#  'A23L': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ FOODS, FOODSTUFFS, OR NON-ALCOHOLIC BEVERAGES, NOT COVERED BY SUBCLASSES ;THEIR PREPARATION OR TREATMENT, e.g. COOKING, MODIFICATION OF NUTRITIVE QUALITIES, PHYSICAL TREATMENT ;PRESERVATION OF FOODS OR FOODSTUFFS, IN GENERAL',
#  'A23N': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ MACHINES OR APPARATUS FOR TREATING HARVESTED FRUIT, VEGETABLES OR FLOWER BULBS IN BULK, NOT OTHERWISE PROVIDED FOR;PEELING VEGETABLES OR FRUIT IN BULK;APPARATUS FOR PREPARING ANIMAL FEEDING- STUFFS ',
#  'A23P': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ SHAPING OR WORKING OF FOODSTUFFS, NOT FULLY COVERED BY A SINGLE OTHER SUBCLASS',
#  'A23V': 'HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ FOODS OR FOODSTUFFS;TREATMENT THEREOF, NOT COVERED BY OTHER CLASSES/ INDEXING SCHEME RELATING TO FOODS, FOODSTUFFS OR NON-ALCOHOLIC BEVERAGES AND LACTIC OR PROPIONIC ACID BACTERIA USED IN FOODSTUFFS OR FOOD PREPARATION',
#  'A24': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES",
#  'A24B': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES/ MANUFACTURE OR PREPARATION OF TOBACCO FOR SMOKING OR CHEWING;TOBACCO;SNUFF",
#  'A24C': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES/ MACHINES FOR MAKING CIGARS OR CIGARETTES",
#  'A24D': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES/ CIGARS;CIGARETTES;TOBACCO SMOKE FILTERS;MOUTHPIECES FOR CIGARS OR CIGARETTES;MANUFACTURE OF TOBACCO SMOKE FILTERS OR MOUTHPIECES",
#  'A24F': "HUMAN NECESSITIES/ FOODSTUFFS;TOBACCO/ TOBACCO;CIGARS;CIGARETTES;SIMULATED SMOKING DEVICES;SMOKERS' REQUISITES/ SMOKERS' REQUISITES;MATCH BOXES;SIMULATED SMOKING DEVICES ",
#  'A41': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL',
#  'A41B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ SHIRTS;UNDERWEAR;BABY LINEN;HANDKERCHIEFS',
#  'A41C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ CORSETS;BRASSIERES',
#  'A41D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ OUTERWEAR;PROTECTIVE GARMENTS;ACCESSORIES',
#  'A41F': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ GARMENT FASTENINGS;SUSPENDERS',
#  'A41G': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ ARTIFICIAL FLOWERS;WIGS;MASKS;FEATHERS',
#  'A41H': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ WEARING APPAREL/ APPLIANCES OR METHODS FOR MAKING CLOTHES, e.g. FOR DRESS-MAKING OR FOR TAILORING, NOT OTHERWISE PROVIDED FOR',
#  'A42': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HEADWEAR',
#  'A42B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HEADWEAR/ HATS;HEAD COVERINGS ',
#  'A42C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HEADWEAR/ MANUFACTURING OR TRIMMING HEAD COVERINGS, e.g. HATS',
#  'A43': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FOOTWEAR',
#  'A43B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FOOTWEAR/ CHARACTERISTIC FEATURES OF FOOTWEAR;PARTS OF FOOTWEAR',
#  'A43C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FOOTWEAR/ FASTENINGS OR ATTACHMENTS OF FOOTWEAR;LACES IN GENERAL',
#  'A43D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FOOTWEAR/ MACHINES, TOOLS, EQUIPMENT OR METHODS FOR MANUFACTURING OR REPAIRING FOOTWEAR',
#  'A44': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HABERDASHERY;JEWELLERY',
#  'A44B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HABERDASHERY;JEWELLERY/ BUTTONS, PINS, BUCKLES, SLIDE FASTENERS, OR THE LIKE ',
#  'A44C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HABERDASHERY;JEWELLERY/ PERSONAL ADORNMENTS, e.g. JEWELLERY;COINS',
#  'A44D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HABERDASHERY;JEWELLERY/ INDEXING SCHEME RELATING TO BUTTONS, PINS, BUCKLES OR SLIDE FASTENERS, AND TO JEWELLERY, BRACELETS OR OTHER PERSONAL ADORNMENTS',
#  'A45': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HAND OR TRAVELLING ARTICLES',
#  'A45B': "HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HAND OR TRAVELLING ARTICLES/ WALKING STICKS ;UMBRELLAS;LADIES' OR LIKE FANS ",
#  'A45C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HAND OR TRAVELLING ARTICLES/ PURSES;LUGGAGE;HAND CARRIED BAGS',
#  'A45D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HAND OR TRAVELLING ARTICLES/ HAIRDRESSING OR SHAVING EQUIPMENT ;EQUIPMENT FOR COSMETICS OR COSMETIC TREATMENTS, e.g. FOR MANICURING OR PEDICURING',
#  'A45F': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ HAND OR TRAVELLING ARTICLES/ TRAVELLING OR CAMP EQUIPMENT: SACKS OR PACKS CARRIED ON THE BODY',
#  'A46': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ BRUSHWARE',
#  'A46B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ BRUSHWARE/ BRUSHES ',
#  'A46D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ BRUSHWARE/ MANUFACTURE OF BRUSHES',
#  'A47': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL',
#  'A47B': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ TABLES;DESKS;OFFICE FURNITURE;CABINETS;DRAWERS;GENERAL DETAILS OF FURNITURE ',
#  'A47C': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ CHAIRS ;SOFAS;BEDS ',
#  'A47D': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ FURNITURE SPECIALLY ADAPTED FOR CHILDREN ',
#  'A47F': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ SPECIAL FURNITURE, FITTINGS, OR ACCESSORIES FOR SHOPS, STOREHOUSES, BARS, RESTAURANTS OR THE LIKE;PAYING COUNTERS',
#  'A47G': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ HOUSEHOLD OR TABLE EQUIPMENT ',
#  'A47H': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ FURNISHINGS FOR WINDOWS OR DOORS ',
#  'A47J': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ KITCHEN EQUIPMENT;COFFEE MILLS;SPICE MILLS;APPARATUS FOR MAKING BEVERAGES',
#  'A47K': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ SANITARY EQUIPMENT NOT OTHERWISE PROVIDED FOR ;TOILET ACCESSORIES ',
#  'A47L': 'HUMAN NECESSITIES/ PERSONAL OR DOMESTIC ARTICLES/ FURNITURE;DOMESTIC ARTICLES OR APPLIANCES;COFFEE MILLS;SPICE MILLS;SUCTION CLEANERS IN GENERAL/ DOMESTIC WASHING OR CLEANING ;SUCTION CLEANERS IN GENERAL ',
#  'A61': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE',
#  'A61B': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ DIAGNOSIS;SURGERY;IDENTIFICATION ',
#  'A61C': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ DENTISTRY;APPARATUS OR METHODS FOR ORAL OR DENTAL HYGIENE ',
#  'A61D': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ VETERINARY INSTRUMENTS, IMPLEMENTS, TOOLS, OR METHODS',
#  'A61F': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ FILTERS IMPLANTABLE INTO BLOOD VESSELS;PROSTHESES;DEVICES PROVIDING PATENCY TO, OR PREVENTING COLLAPSING OF, TUBULAR STRUCTURES OF THE BODY, e.g. STENTS;ORTHOPAEDIC, NURSING OR CONTRACEPTIVE DEVICES;FOMENTATION;TREATMENT OR PROTECTION OF EYES OR EARS;BANDAGES, DRESSINGS OR ABSORBENT PADS;FIRST-AID KITS ',
#  'A61G': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ TRANSPORT, PERSONAL CONVEYANCES, OR ACCOMMODATION SPECIALLY ADAPTED FOR PATIENTS OR DISABLED PERSONS ;OPERATING TABLES OR CHAIRS;CHAIRS FOR DENTISTRY;FUNERAL DEVICES ',
#  'A61H': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ PHYSICAL THERAPY APPARATUS, e.g. DEVICES FOR LOCATING OR STIMULATING REFLEX POINTS IN THE BODY;ARTIFICIAL RESPIRATION;MASSAGE;BATHING DEVICES FOR SPECIAL THERAPEUTIC OR HYGIENIC PURPOSES OR SPECIFIC PARTS OF THE BODY ',
#  'A61J': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ CONTAINERS SPECIALLY ADAPTED FOR MEDICAL OR PHARMACEUTICAL PURPOSES;DEVICES OR METHODS SPECIALLY ADAPTED FOR BRINGING PHARMACEUTICAL PRODUCTS INTO PARTICULAR PHYSICAL OR ADMINISTERING FORMS;DEVICES FOR ADMINISTERING FOOD OR MEDICINES ORALLY;BABY COMFORTERS;DEVICES FOR RECEIVING SPITTLE',
#  'A61K': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ PREPARATIONS FOR MEDICAL, DENTAL OR TOILETRY PURPOSES ',
#  'A61L': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ METHODS OR APPARATUS FOR STERILISING MATERIALS OR OBJECTS IN GENERAL;DISINFECTION, STERILISATION OR DEODORISATION OF AIR;CHEMICAL ASPECTS OF BANDAGES, DRESSINGS, ABSORBENT PADS OR SURGICAL ARTICLES;MATERIALS FOR BANDAGES, DRESSINGS, ABSORBENT PADS OR SURGICAL ARTICLES ',
#  'A61M': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ DEVICES FOR INTRODUCING MEDIA INTO, OR ONTO, THE BODY ;DEVICES FOR TRANSDUCING BODY MEDIA OR FOR TAKING MEDIA FROM THE BODY ;DEVICES FOR PRODUCING OR ENDING SLEEP OR STUPOR ',
#  'A61N': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ ELECTROTHERAPY;MAGNETOTHERAPY;RADIATION THERAPY;ULTRASOUND THERAPY ',
#  'A61P': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ SPECIFIC THERAPEUTIC ACTIVITY OF CHEMICAL COMPOUNDS OR MEDICINAL PREPARATIONS',
#  'A61Q': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ MEDICAL OR VETERINARY SCIENCE;HYGIENE/ SPECIFIC USE OF COSMETICS OR SIMILAR TOILETRY PREPARATIONS',
#  'A62': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ LIFE-SAVING;FIRE-FIGHTING',
#  'A62B': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ LIFE-SAVING;FIRE-FIGHTING/ DEVICES, APPARATUS OR METHODS FOR LIFE-SAVING ',
#  'A62C': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ LIFE-SAVING;FIRE-FIGHTING/ FIRE-FIGHTING ',
#  'A62D': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ LIFE-SAVING;FIRE-FIGHTING/ CHEMICAL MEANS FOR EXTINGUISHING FIRES OR FOR COMBATING OR PROTECTING AGAINST HARMFUL CHEMICAL AGENTS;CHEMICAL MATERIALS FOR USE IN BREATHING APPARATUS',
#  'A63': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS',
#  'A63B': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ APPARATUS FOR PHYSICAL TRAINING, GYMNASTICS, SWIMMING, CLIMBING, OR FENCING;BALL GAMES;TRAINING EQUIPMENT ',
#  'A63C': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ SKATES;SKIS;ROLLER SKATES;DESIGN OR LAYOUT OF COURTS, RINKS OR THE LIKE ',
#  'A63D': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ BOWLING GAMES, e.g. SKITTLES, BOCCE OR BOWLS;INSTALLATIONS THEREFOR;BAGATELLE OR SIMILAR GAMES;BILLIARDS ',
#  'A63F': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ CARD, BOARD, OR ROULETTE GAMES;INDOOR GAMES USING SMALL MOVING PLAYING BODIES;VIDEO GAMES;GAMES NOT OTHERWISE PROVIDED FOR',
#  'A63G': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ MERRY-GO-ROUNDS;SWINGS;ROCKING-HORSES;CHUTES;SWITCHBACKS;SIMILAR DEVICES FOR PUBLIC AMUSEMENT',
#  'A63H': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ TOYS, e.g. TOPS, DOLLS, HOOPS OR BUILDING BLOCKS',
#  'A63J': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ DEVICES FOR THEATRES, CIRCUSES, OR THE LIKE;CONJURING APPLIANCES OR THE LIKE',
#  'A63K': 'HUMAN NECESSITIES/ HEALTH;AMUSEMENT/ SPORTS;GAMES;AMUSEMENTS/ RACING;RIDING SPORTS;EQUIPMENT OR ACCESSORIES THEREFOR ',
#  'A99': 'HUMAN NECESSITIES/ SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION',
#  'A99Z': 'HUMAN NECESSITIES/ SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION/ SUBJECT MATTER NOT OTHERWISE PROVIDED FOR IN THIS SECTION',
#  'B': 'PERFORMING OPERATIONS;TRANSPORTING',
#  'B01': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL',
#  'B01B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL/ BOILING;BOILING APPARATUS ;; EVAPORATION; EVAPORATION APPARATUS',
#  'B01D': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL/ SEPARATION ',
#  'B01F': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL/ MIXING, e.g. DISSOLVING, EMULSIFYING OR DISPERSING ',
#  'B01J': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL/ CHEMICAL OR PHYSICAL PROCESSES, e.g. CATALYSIS OR COLLOID CHEMISTRY;THEIR RELEVANT APPARATUS',
#  'B01L': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ PHYSICAL OR CHEMICAL PROCESSES OR APPARATUS IN GENERAL/ CHEMICAL OR PHYSICAL LABORATORY APPARATUS FOR GENERAL USE',
#  'B02': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING',
#  'B02B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING/ PREPARING GRAIN FOR MILLING;REFINING GRANULAR FRUIT TO COMMERCIAL PRODUCTS BY WORKING THE SURFACE ',
#  'B02C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CRUSHING, PULVERISING, OR DISINTEGRATING;PREPARATORY TREATMENT OF GRAIN FOR MILLING/ CRUSHING, PULVERISING, OR DISINTEGRATING IN GENERAL;MILLING GRAIN ',
#  'B03': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS',
#  'B03B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS/ SEPARATING SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS',
#  'B03C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS/ MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS ',
#  'B03D': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATION OF SOLID MATERIALS USING LIQUIDS OR USING PNEUMATIC TABLES OR JIGS;MAGNETIC OR ELECTROSTATIC SEPARATION OF SOLID MATERIALS FROM SOLID MATERIALS OR FLUIDS;SEPARATION BY HIGH-VOLTAGE ELECTRIC FIELDS/ FLOTATION;DIFFERENTIAL SEDIMENTATION ',
#  'B04': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES',
#  'B04B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES/ CENTRIFUGES ',
#  'B04C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CENTRIFUGAL APPARATUS OR MACHINES FOR CARRYING-OUT PHYSICAL OR CHEMICAL PROCESSES/ APPARATUS USING FREE VORTEX FLOW, e.g. CYCLONES ',
#  'B05': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL',
#  'B05B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL/ SPRAYING APPARATUS;ATOMISING APPARATUS;NOZZLES ',
#  'B05C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL/ APPARATUS FOR APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL ',
#  'B05D': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SPRAYING OR ATOMISING IN GENERAL;APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL/ PROCESSES FOR APPLYING FLUENT MATERIALS TO SURFACES, IN GENERAL ',
#  'B06': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS IN GENERAL',
#  'B06B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS IN GENERAL/ METHODS OR APPARATUS FOR GENERATING OR TRANSMITTING MECHANICAL VIBRATIONS OF INFRASONIC, SONIC, OR ULTRASONIC FREQUENCY, ;e.g.',
#  'B07': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATING SOLIDS FROM SOLIDS;SORTING',
#  'B07B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATING SOLIDS FROM SOLIDS;SORTING/ SEPARATING SOLIDS FROM SOLIDS BY SIEVING, SCREENING, SIFTING OR BY USING GAS CURRENTS;SEPARATING BY OTHER DRY METHODS APPLICABLE TO BULK MATERIAL, e.g. LOOSE ARTICLES FIT TO BE HANDLED LIKE BULK MATERIAL ',
#  'B07C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ SEPARATING SOLIDS FROM SOLIDS;SORTING/ POSTAL SORTING;SORTING INDIVIDUAL ARTICLES, OR BULK MATERIAL FIT TO BE SORTED PIECE-MEAL, e.g. BY PICKING ',
#  'B08': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CLEANING',
#  'B08B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ CLEANING/ CLEANING IN GENERAL;PREVENTION OF FOULING IN GENERAL ',
#  'B09': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL',
#  'B09B': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL/ DISPOSAL OF SOLID WASTE NOT OTHERWISE PROVIDED FOR',
#  'B09C': 'PERFORMING OPERATIONS;TRANSPORTING/ SEPARATING;MIXING/ DISPOSAL OF SOLID WASTE;RECLAMATION OF CONTAMINATED SOIL/ RECLAMATION OF CONTAMINATED SOIL ',
#  'B21': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL',
#  'B21B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ ROLLING OF METAL ',
#  'B21C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ MANUFACTURE OF METAL SHEETS, WIRE, RODS, TUBES OR PROFILES, OTHERWISE THAN BY ROLLING;AUXILIARY OPERATIONS USED IN CONNECTION WITH METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL',
#  'B21D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ WORKING OR PROCESSING OF SHEET METAL OR METAL TUBES, RODS OR PROFILES WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL ',
#  'B21F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ WORKING OR PROCESSING OF METAL WIRE ',
#  'B21G': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ MAKING NEEDLES, PINS OR NAILS OF METAL',
#  'B21H': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ MAKING PARTICULAR METAL OBJECTS BY ROLLING, e.g. SCREWS, WHEELS, RINGS, BARRELS, BALLS ',
#  'B21J': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ FORGING;HAMMERING;PRESSING METAL;RIVETING;FORGE FURNACES ',
#  'B21K': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ MAKING FORGED OR PRESSED METAL PRODUCTS, e.g. HORSE-SHOES, RIVETS, BOLTS OR WHEELS ',
#  'B21L': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MECHANICAL METAL-WORKING WITHOUT ESSENTIALLY REMOVING MATERIAL;PUNCHING METAL/ MAKING METAL CHAINS ',
#  'B22': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ CASTING;POWDER METALLURGY',
#  'B22C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ CASTING;POWDER METALLURGY/ FOUNDRY MOULDING ',
#  'B22D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ CASTING;POWDER METALLURGY/ CASTING OF METALS;CASTING OF OTHER SUBSTANCES BY THE SAME PROCESSES OR DEVICES ',
#  'B22F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ CASTING;POWDER METALLURGY/ WORKING METALLIC POWDER;MANUFACTURE OF ARTICLES FROM METALLIC POWDER;MAKING METALLIC POWDER ;APPARATUS OR DEVICES SPECIALLY ADAPTED FOR METALLIC POWDER',
#  'B23': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR',
#  'B23B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ TURNING;BORING ',
#  'B23C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ MILLING ',
#  'B23D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ PLANING;SLOTTING;SHEARING;BROACHING;SAWING;FILING;SCRAPING;LIKE OPERATIONS FOR WORKING METAL BY REMOVING MATERIAL, NOT OTHERWISE PROVIDED FOR ',
#  'B23F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ MAKING GEARS OR TOOTHED RACKS ',
#  'B23G': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ THREAD CUTTING;WORKING OF SCREWS, BOLT HEADS, OR NUTS, IN CONJUNCTION THEREWITH ',
#  'B23H': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ WORKING OF METAL BY THE ACTION OF A HIGH CONCENTRATION OF ELECTRIC CURRENT ON A WORKPIECE USING AN ELECTRODE WHICH TAKES THE PLACE OF A TOOL;SUCH WORKING COMBINED WITH OTHER FORMS OF WORKING OF METAL ',
#  'B23K': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ SOLDERING OR UNSOLDERING;WELDING;CLADDING OR PLATING BY SOLDERING OR WELDING;CUTTING BY APPLYING HEAT LOCALLY, e.g. FLAME CUTTING;WORKING BY LASER BEAM ',
#  'B23P': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ METAL-WORKING NOT OTHERWISE PROVIDED FOR;COMBINED OPERATIONS;UNIVERSAL MACHINE TOOLS ',
#  'B23Q': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MACHINE TOOLS;METAL-WORKING NOT OTHERWISE PROVIDED FOR/ DETAILS, COMPONENTS, OR ACCESSORIES FOR MACHINE TOOLS, e.g. ARRANGEMENTS FOR COPYING OR CONTROLLING ;MACHINE TOOLS IN GENERAL CHARACTERISED BY THE CONSTRUCTION OF PARTICULAR DETAILS OR COMPONENTS;COMBINATIONS OR ASSOCIATIONS OF METAL-WORKING MACHINES, NOT DIRECTED TO A PARTICULAR RESULT',
#  'B24': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ GRINDING;POLISHING',
#  'B24B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ GRINDING;POLISHING/ MACHINES, DEVICES, OR PROCESSES FOR GRINDING OR POLISHING ;DRESSING OR CONDITIONING OF ABRADING SURFACES;FEEDING OF GRINDING, POLISHING, OR LAPPING AGENTS',
#  'B24C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ GRINDING;POLISHING/ ABRASIVE OR RELATED BLASTING WITH PARTICULATE MATERIAL',
#  'B24D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ GRINDING;POLISHING/ TOOLS FOR GRINDING, BUFFING OR SHARPENING ',
#  'B25': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS',
#  'B25B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ TOOLS OR BENCH DEVICES NOT OTHERWISE PROVIDED FOR, FOR FASTENING, CONNECTING, DISENGAGING OR HOLDING',
#  'B25C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ HAND-HELD NAILING OR STAPLING TOOLS;MANUALLY OPERATED PORTABLE STAPLING TOOLS ',
#  'B25D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ PERCUSSIVE TOOLS ',
#  'B25F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ COMBINATION OR MULTI-PURPOSE TOOLS NOT OTHERWISE PROVIDED FOR;DETAILS OR COMPONENTS OF PORTABLE POWER-DRIVEN TOOLS NOT PARTICULARLY RELATED TO THE OPERATIONS PERFORMED AND NOT OTHERWISE PROVIDED FOR ',
#  'B25G': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ HANDLES FOR HAND IMPLEMENTS ',
#  'B25H': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ WORKSHOP EQUIPMENT, e.g. FOR MARKING-OUT WORK;STORAGE MEANS FOR WORKSHOPS ',
#  'B25J': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND TOOLS;PORTABLE POWER-DRIVEN TOOLS;MANIPULATORS/ MANIPULATORS;CHAMBERS PROVIDED WITH MANIPULATION DEVICES ',
#  'B26': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND CUTTING TOOLS;CUTTING;SEVERING',
#  'B26B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND CUTTING TOOLS;CUTTING;SEVERING/ HAND-HELD CUTTING TOOLS NOT OTHERWISE PROVIDED FOR ',
#  'B26D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND CUTTING TOOLS;CUTTING;SEVERING/ CUTTING;DETAILS COMMON TO MACHINES FOR PERFORATING, PUNCHING, CUTTING-OUT, STAMPING-OUT OR SEVERING ',
#  'B26F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ HAND CUTTING TOOLS;CUTTING;SEVERING/ PERFORATING;PUNCHING;CUTTING-OUT;STAMPING-OUT;SEVERING BY MEANS OTHER THAN CUTTING ',
#  'B27': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL',
#  'B27B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ SAWS FOR WOOD OR SIMILAR MATERIAL;COMPONENTS OR ACCESSORIES THEREFOR ',
#  'B27C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ PLANING, DRILLING, MILLING, TURNING OR UNIVERSAL MACHINES FOR WOOD OR SIMILAR MATERIAL ',
#  'B27D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ WORKING VENEER OR PLYWOOD ',
#  'B27F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ DOVETAILED WORK;TENONS;SLOTTING MACHINES FOR WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES ',
#  'B27G': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ ACCESSORY MACHINES OR APPARATUS FOR WORKING WOOD OR SIMILAR MATERIALS;TOOLS FOR WORKING WOOD OR SIMILAR MATERIALS ;SAFETY DEVICES FOR WOOD WORKING MACHINES OR TOOLS',
#  'B27H': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ BENDING WOOD OR SIMILAR MATERIAL;COOPERAGE;MAKING WHEELS FROM WOOD OR SIMILAR MATERIAL',
#  'B27J': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ MECHANICAL WORKING OF CANE, CORK, OR SIMILAR MATERIALS',
#  'B27K': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ PROCESSES, APPARATUS OR SELECTION OF SUBSTANCES FOR IMPREGNATING, STAINING, DYEING, BLEACHING OF WOOD OR SIMILAR MATERIALS, OR TREATING OF WOOD OR SIMILAR MATERIALS WITH PERMEANT LIQUIDS, NOT OTHERWISE PROVIDED FOR ;CHEMICAL OR PHYSICAL TREATMENT OF CORK, CANE, REED, STRAW OR SIMILAR MATERIALS',
#  'B27L': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ REMOVING BARK OR VESTIGES OF BRANCHES ;SPLITTING WOOD;MANUFACTURE OF VENEER, WOODEN STICKS, WOOD SHAVINGS, WOOD FIBRES OR WOOD POWDER',
#  'B27M': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ WORKING OF WOOD NOT PROVIDED FOR IN SUBCLASSES ;MANUFACTURE OF SPECIFIC WOODEN ARTICLES',
#  'B27N': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OR PRESERVING WOOD OR SIMILAR MATERIAL;NAILING OR STAPLING MACHINES IN GENERAL/ MANUFACTURE BY DRY PROCESSES OF ARTICLES, WITH OR WITHOUT ORGANIC BINDING AGENTS, MADE FROM PARTICLES OR FIBRES CONSISTING OF WOOD OR OTHER LIGNOCELLULOSIC OR LIKE ORGANIC MATERIAL ',
#  'B28': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING CEMENT, CLAY, OR STONE',
#  'B28B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING CEMENT, CLAY, OR STONE/ SHAPING CLAY OR OTHER CERAMIC COMPOSITIONS;SHAPING SLAG;SHAPING MIXTURES CONTAINING CEMENTITIOUS MATERIAL, e.g. PLASTER ',
#  'B28C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING CEMENT, CLAY, OR STONE/ PREPARING CLAY;PRODUCING MIXTURES CONTAINING CLAY OR CEMENTITIOUS MATERIAL, e.g. PLASTER ',
#  'B28D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING CEMENT, CLAY, OR STONE/ WORKING STONE OR STONE-LIKE MATERIALS',
#  'B29': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL',
#  'B29B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL/ PREPARATION OR PRETREATMENT OF THE MATERIAL TO BE SHAPED;MAKING GRANULES OR PREFORMS;RECOVERY OF PLASTICS OR OTHER CONSTITUENTS OF WASTE MATERIAL CONTAINING PLASTICS',
#  'B29C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL/ SHAPING OR JOINING OF PLASTICS;SHAPING OF MATERIAL IN A PLASTIC STATE, NOT OTHERWISE PROVIDED FOR;AFTER-TREATMENT OF THE SHAPED PRODUCTS, e.g. REPAIRING ',
#  'B29D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL/ PRODUCING PARTICULAR ARTICLES FROM PLASTICS OR FROM SUBSTANCES IN A PLASTIC STATE ',
#  'B29K': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL/ INDEXING SCHEME ASSOCIATED WITH SUBCLASSES ;MOULDS, ',
#  'B29L': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ WORKING OF PLASTICS;WORKING OF SUBSTANCES IN A PLASTIC STATE IN GENERAL/ INDEXING SCHEME ASSOCIATED WITH SUBCLASS ',
#  'B30': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ PRESSES',
#  'B30B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ PRESSES/ PRESSES IN GENERAL ',
#  'B31': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#  'B31B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER/ MAKING CONTAINERS OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER ',
#  'B31C': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER/ MAKING WOUND ARTICLES, e.g. WOUND TUBES, OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER',
#  'B31D': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER, NOT PROVIDED FOR IN SUBCLASSES ',
#  'B31F': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ MAKING ARTICLES OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER;WORKING PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER/ MECHANICAL WORKING OR DEFORMATION OF PAPER, CARDBOARD OR MATERIAL WORKED IN A MANNER ANALOGOUS TO PAPER ',
#  'B32': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ LAYERED PRODUCTS',
#  'B32B': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ LAYERED PRODUCTS/ LAYERED PRODUCTS, i.e. PRODUCTS BUILT-UP OF STRATA OF FLAT OR NON-FLAT, e.g. CELLULAR OR HONEYCOMB, FORM',
#  'B33': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ ADDITIVE MANUFACTURING TECHNOLOGY',
#  'B33Y': 'PERFORMING OPERATIONS;TRANSPORTING/ SHAPING/ ADDITIVE MANUFACTURING TECHNOLOGY/ ADDITIVE MANUFACTURING, i.e. MANUFACTURING OF THREE-DIMENSIONAL [3-D] OBJECTS BY ADDITIVE DEPOSITION, ADDITIVE AGGLOMERATION OR ADDITIVE LAYERING, e.g. BY 3-D PRINTING, STEREOLITHOGRAPHY OR SELECTIVE LASER SINTERING',
#  'B41': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS',
#  'B41B': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ MACHINES OR ACCESSORIES FOR MAKING, SETTING, OR DISTRIBUTING TYPE;TYPE;PHOTOGRAPHIC OR PHOTOELECTRIC COMPOSING DEVICES ',
#  'B41C': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ PROCESSES FOR THE MANUFACTURE OR REPRODUCTION OF PRINTING SURFACES ',
#  'B41D': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ APPARATUS FOR THE MECHANICAL REPRODUCTION OF PRINTING SURFACES FOR STEREOTYPE PRINTING;SHAPING ELASTIC OR DEFORMABLE MATERIAL TO FORM PRINTING SURFACES ',
#  'B41F': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ PRINTING MACHINES OR PRESSES ',
#  'B41G': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ APPARATUS FOR BRONZE PRINTING, LINE PRINTING, OR FOR BORDERING OR EDGING SHEETS OR LIKE ARTICLES;AUXILIARY FOR PERFORATING IN CONJUNCTION WITH PRINTING ',
#  'B41J': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ TYPEWRITERS;SELECTIVE PRINTING MECHANISMS, i.e. MECHANISMS PRINTING OTHERWISE THAN FROM A FORME;CORRECTION OF TYPOGRAPHICAL ERRORS',
#  'B41K': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ STAMPS;STAMPING OR NUMBERING APPARATUS OR DEVICES ',
#  'B41L': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ APPARATUS OR DEVICES FOR MANIFOLDING, DUPLICATING OR PRINTING FOR OFFICE OR OTHER COMMERCIAL PURPOSES;ADDRESSING MACHINES OR LIKE SERIES-PRINTING MACHINES ',
#  'B41M': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ PRINTING, DUPLICATING, MARKING, OR COPYING PROCESSES;COLOUR PRINTING, ',
#  'B41N': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ PRINTING PLATES OR FOILS ;MATERIALS FOR SURFACES USED IN PRINTING MACHINES FOR PRINTING, INKING, DAMPING, OR THE LIKE;PREPARING SUCH SURFACES FOR USE AND CONSERVING THEM',
#  'B41P': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ PRINTING;LINING MACHINES;TYPEWRITERS;STAMPS/ INDEXING SCHEME RELATING TO PRINTING, LINING MACHINES, TYPEWRITERS, AND TO STAMPS',
#  'B42': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER',
#  'B42B': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER/ PERMANENTLY ATTACHING TOGETHER SHEETS, QUIRES OR SIGNATURES OR PERMANENTLY ATTACHING OBJECTS THERETO ',
#  'B42C': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER/ BOOKBINDING ',
#  'B42D': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER/ BOOKS;BOOK COVERS;LOOSE LEAVES;PRINTED MATTER CHARACTERISED BY IDENTIFICATION OR SECURITY FEATURES; PRINTED MATTER OF SPECIAL FORMAT OR STYLE NOT OTHERWISE PROVIDED FOR;DEVICES FOR USE THEREWITH AND NOT OTHERWISE PROVIDED FOR;MOVABLE-STRIP WRITING OR READING APPARATUS',
#  'B42F': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER/ SHEETS TEMPORARILY ATTACHED TOGETHER;FILING APPLIANCES;FILE CARDS;INDEXING ',
#  'B42P': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ BOOKBINDING;ALBUMS;FILES;SPECIAL PRINTED MATTER/ INDEXING SCHEME RELATING TO BOOKS, FILING APPLIANCES OR THE LIKE',
#  'B43': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES',
#  'B43K': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES/ IMPLEMENTS FOR WRITING OR DRAWING ',
#  'B43L': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES/ ARTICLES FOR WRITING OR DRAWING UPON; ;WRITING OR DRAWING AIDS;',
#  'B43M': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ WRITING OR DRAWING IMPLEMENTS;BUREAU ACCESSORIES/ BUREAU ACCESSORIES NOT OTHERWISE PROVIDED FOR ',
#  'B44': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ DECORATIVE ARTS',
#  'B44B': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ DECORATIVE ARTS/ MACHINES, APPARATUS OR TOOLS FOR ARTISTIC WORK, e.g. FOR SCULPTURING, GUILLOCHING, CARVING, BRANDING, INLAYING ',
#  'B44C': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ DECORATIVE ARTS/ PRODUCING DECORATIVE EFFECTS ;MOSAICS;TARSIA WORK ;PAPERHANGING ',
#  'B44D': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ DECORATIVE ARTS/ PAINTING OR ARTISTIC DRAWING, NOT OTHERWISE PROVIDED FOR;PRESERVING PAINTINGS;SURFACE TREATMENT TO OBTAIN SPECIAL ARTISTIC SURFACE EFFECTS OR FINISHES ',
#  'B44F': 'PERFORMING OPERATIONS;TRANSPORTING/ PRINTING/ DECORATIVE ARTS/ SPECIAL DESIGNS OR PICTURES',
#  'B60': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL',
#  'B60B': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLE WHEELS ;CASTORS;AXLES FOR WHEELS OR CASTORS;INCREASING WHEEL ADHESION',
#  'B60C': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLE TYRES;TYRE INFLATION;TYRE CHANGING;CONNECTING VALVES TO INFLATABLE ELASTIC BODIES IN GENERAL;DEVICES OR ARRANGEMENTS RELATED TO TYRES',
#  'B60D': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLE CONNECTIONS ',
#  'B60F': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLES FOR USE BOTH ON RAIL AND ON ROAD;AMPHIBIOUS OR LIKE VEHICLES;CONVERTIBLE VEHICLES ',
#  'B60G': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLE SUSPENSION ARRANGEMENTS ',
#  'B60H': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ ARRANGEMENTS OF HEATING, COOLING, VENTILATING OR OTHER AIR-TREATING DEVICES SPECIALLY ADAPTED FOR PASSENGER OR GOODS SPACES OF VEHICLES',
#  'B60J': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ WINDOWS, WINDSCREENS, NON-FIXED ROOFS, DOORS, OR SIMILAR DEVICES FOR VEHICLES;REMOVABLE EXTERNAL PROTECTIVE COVERINGS SPECIALLY ADAPTED FOR VEHICLES ',
#  'B60K': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ ARRANGEMENT OR MOUNTING OF PROPULSION UNITS OR OF TRANSMISSIONS IN VEHICLES;ARRANGEMENT OR MOUNTING OF PLURAL DIVERSE PRIME-MOVERS IN VEHICLES;AUXILIARY DRIVES FOR VEHICLES;INSTRUMENTATION OR DASHBOARDS FOR VEHICLES;ARRANGEMENTS IN CONNECTION WITH COOLING, AIR INTAKE, GAS EXHAUST OR FUEL SUPPLY OF PROPULSION UNITS IN VEHICLES',
#  'B60L': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ PROPULSION OF ELECTRICALLY-PROPELLED VEHICLES ;SUPPLYING ELECTRIC POWER FOR AUXILIARY EQUIPMENT OF ELECTRICALLY-PROPELLED VEHICLES ;ELECTRODYNAMIC BRAKE SYSTEMS FOR VEHICLES IN GENERAL ;MAGNETIC SUSPENSION OR LEVITATION FOR VEHICLES;MONITORING OPERATING VARIABLES OF ELECTRICALLY-PROPELLED VEHICLES;ELECTRIC SAFETY DEVICES FOR ELECTRICALLY-PROPELLED VEHICLES',
#  'B60M': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ POWER SUPPLY LINES, AND DEVICES ALONG RAILS, FOR ELECTRICALLY- PROPELLED VEHICLES ',
#  'B60N': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ SEATS SPECIALLY ADAPTED FOR VEHICLES;VEHICLE PASSENGER ACCOMMODATION NOT OTHERWISE PROVIDED FOR',
#  'B60P': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLES ADAPTED FOR LOAD TRANSPORTATION OR TO TRANSPORT, TO CARRY, OR TO COMPRISE SPECIAL LOADS OR OBJECTS ',
#  'B60Q': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ ARRANGEMENT OF SIGNALLING OR LIGHTING DEVICES, THE MOUNTING OR SUPPORTING THEREOF OR CIRCUITS THEREFOR, FOR VEHICLES IN GENERAL',
#  'B60R': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLES, VEHICLE FITTINGS, OR VEHICLE PARTS, NOT OTHERWISE PROVIDED FOR',
#  'B60S': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ SERVICING, CLEANING, REPAIRING, SUPPORTING, LIFTING, OR MANOEUVRING OF VEHICLES, NOT OTHERWISE PROVIDED FOR',
#  'B60T': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ VEHICLE BRAKE CONTROL SYSTEMS OR PARTS THEREOF;BRAKE CONTROL SYSTEMS OR PARTS THEREOF, IN GENERAL ;ARRANGEMENT OF BRAKING ELEMENTS ON VEHICLES IN GENERAL;PORTABLE DEVICES FOR PREVENTING UNWANTED MOVEMENT OF VEHICLES;VEHICLE MODIFICATIONS TO FACILITATE COOLING OF BRAKES',
#  'B60V': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ AIR-CUSHION VEHICLES',
#  'B60W': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ CONJOINT CONTROL OF VEHICLE SUB-UNITS OF DIFFERENT TYPE OR DIFFERENT FUNCTION;CONTROL SYSTEMS SPECIALLY ADAPTED FOR HYBRID VEHICLES;ROAD VEHICLE DRIVE CONTROL SYSTEMS FOR PURPOSES NOT RELATED TO THE CONTROL OF A PARTICULAR SUB-UNIT',
#  'B60Y': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ VEHICLES IN GENERAL/ INDEXING SCHEME RELATING TO ASPECTS CROSS-CUTTING VEHICLE TECHNOLOGY',
#  'B61': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS',
#  'B61B': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS/ RAILWAY SYSTEMS;EQUIPMENT THEREFOR NOT OTHERWISE PROVIDED FOR ',
#  'B61C': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS/ LOCOMOTIVES;MOTOR RAILCARS ',
#  'B61D': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS/ BODY DETAILS OR KINDS OF RAILWAY VEHICLES ',
#  'B61F': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS/ RAIL VEHICLE SUSPENSIONS, e.g. UNDERFRAMES, BOGIES OR ARRANGEMENTS OF WHEEL AXLES;RAIL VEHICLES FOR USE ON TRACKS OF DIFFERENT WIDTH;PREVENTING DERAILING OF RAIL VEHICLES;WHEEL GUARDS, OBSTRUCTION REMOVERS OR THE LIKE FOR RAIL VEHICLES ',
#  'B61G': 'PERFORMING OPERATIONS;TRANSPORTING/ TRANSPORTING/ RAILWAYS/ COUPLINGS;DRAUGHT AND BUFFING APPLIANCES ',
# ...
#  'A01B33025': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on horizontal shaft transverse to direction of travel/ with spring tools, i.e. resiliently- or flexibly-attached rigid tools',
#  'A01B33027': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on horizontal shaft transverse to direction of travel/ Operator supported tools, e.g. using a harness for supporting the tool or power unit',
#  'A01B33028': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on horizontal shaft transverse to direction of travel/ of the walk-behind type ',
#  'A01B3304': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on horizontal shaft parallel to direction of travel',
#  'A01B3306': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on vertical or steeply-inclined shaft',
#  'A01B33065': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with tools on vertical or steeply-inclined shaft/ comprising a plurality of rotors carried by an elongate, substantially closed transmission casing, transversely connectable to a tractor',
#  'A01B3308': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings',
#  'A01B33082': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Transmissions; Gearings; Power distribution',
#  'A01B33085': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Transmissions; Gearings; Power distribution/ specially adapted for tools on a vertical shaft',
#  'A01B33087': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Lifting devices; Depth regulation devices; Mountings',
#  'A01B3310': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Structural or functional features of the tools ;; Theoretical aspects of the cutting action',
#  'A01B33103': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Structural or functional features of the tools ;; Theoretical aspects of the cutting action/ the rotating shaft being oriented horizontally',
#  'A01B33106': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Structural or functional features of the tools ;; Theoretical aspects of the cutting action/ the rotating shaft being oriented vertically or steeply inclined',
#  'A01B3312': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Arrangement of the tools;Screening of the tools',
#  'A01B33125': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Arrangement of the tools;Screening of the tools/ screening of tools rotating about a vertical shaft',
#  'A01B3314': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly',
#  'A01B33142': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly/ the rotating shaft being oriented horizontally',
#  'A01B33144': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly/ the rotating shaft being oriented horizontally/ with spring tools or resiliently-attached rigid tools',
#  'A01B33146': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly/ the rotating shaft being oriented vertically or steeply inclined',
#  'A01B33148': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ Tools;Details, e.g. adaptations of transmissions or gearings/ Attaching the tools to the rotating shaft, e.g. resiliently ;or flexibly/ the rotating shaft being oriented vertically or steeply inclined/ with spring tools or resiliently-attached rigid tools',
#  'A01B3316': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Tilling implements with rotary driven tools ;, e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs/ with special additional arrangements ',
#  'A01B3500': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing',
#  'A01B3502': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools',
#  'A01B3504': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ drawn by animal or tractor ;or man-power',
#  'A01B3506': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ drawn by animal or tractor ;or man-power/ with spring tools ;or with resiliently- or flexibly-attached rigid tools',
#  'A01B3508': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ drawn by animal or tractor ;or man-power/ with rigid tools',
#  'A01B3510': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ mounted on tractors',
#  'A01B3512': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ mounted on tractors/ with spring tools ;or with resiliently-or flexibly-attached rigid tools',
#  'A01B3514': 'HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;TRAPPING;FISHING/ SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL / Other machines for working soil/ Other machines for working soil ;not specially adapted for working soil on which crops are growing/ with non-rotating tools/ mounted on tractors/ with rigid tools',
#  ...}

# %%
symbols=list(withoutSlashDict.keys())
definitions=list(withoutSlashDict.values())

# %%
print(len(symbols))
print(len(definitions))
# Out:
# 260419
# 260419

# %%
df=pd.DataFrame({
    'symbols':symbols,
    'definitions':definitions
})

# %%
df
# Out:
#             symbols                                        definitions
# 0                 A                                  HUMAN NECESSITIES
# 1               A01  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 2              A01B  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 3              A01C  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 4              A01D  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# ...             ...                                                ...
# 260414  Y10T4831864  GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPME...
# 260415  Y10T4831873  GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPME...
# 260416  Y10T4831882  GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPME...
# 260417  Y10T4831891  GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPME...
# 260418    Y10T48319  GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPME...
#
# [260419 rows x 2 columns]

# %%
#tokenisation
tok_def=Tokenizer()
tok_def.fit_on_texts(definitions)
word_index = tok_def.word_index
seq_def=tok_def.texts_to_sequences(definitions)

# %%
len(seq_def)
# Out:
# 260419

# %%
max_seq_length=max([len(seq) for seq in seq_def])

# %%
max_seq_length
# Out:
# 231

# %%
pad_seq=pad_sequences(seq_def,maxlen=max_seq_length,padding='post')

# %%
len(pad_seq)
# Out:
# 260419

# %%
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(symbols)

# %%
encoded_labels.shape
# Out:
# (260419,)

# %%
x_train,x_test,y_train,y_test=train_test_split(pad_seq,encoded_labels,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (208335, 231)
# (52084, 231)
# (208335,)
# (52084,)

# %%
model = Sequential()
model.add(Embedding(input_dim=len(word_index) + 1, output_dim=100, input_length=max_seq_length))
model.add(LSTM(units=128))
model.add(Dense(units=len(set(symbols)), activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=2, verbose=1, batch_size=64,validation_split=0.1)
# Out:
# Epoch 1/2
# 2930/2930 [==============================] - 3469s 1s/step - loss: 12.8909 - accuracy: 0.0000e+00 - val_loss: 13.3248 - val_accuracy: 0.0000e+00
# Epoch 2/2
# 2930/2930 [==============================] - 3807s 1s/step - loss: 12.4624 - accuracy: 0.0000e+00 - val_loss: 15.0868 - val_accuracy: 0.0000e+00

# %%
import json 
import pandas as pd

# %%
file="C:\\Users\\pooja\\Downloads\\JSONFiles\\A\\A01B100.json"
with open(file,'r') as filename:
    data=json.load(filename)
df=pd.DataFrame([data])
df
# Out:
#   keyWithSlash keywithoutSlash  \
# 0     A01B1/00         A01B100
#
#                                           Definition     last_def
# 0  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...  Hand tools

# %%
file="C:\\Users\\pooja\\Downloads\\JSONFiles\\A\\A.json"
with open(file,'r') as filename:
    data=json.load(filename)
new_df=pd.DataFrame([data])
df=pd.concat([df,new_df],ignore_index=True)
df
# Out:
#   keyWithSlash keywithoutSlash  \
# 0     A01B1/00         A01B100
# 1         A01B            A01B
# 2          A01             A01
# 3            A               A
#
#                                           Definition  \
# 0  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 1  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 2  HUMAN NECESSITIES/ AGRICULTURE/ AGRICULTURE;FO...
# 3                                  HUMAN NECESSITIES
#
#                                             last_def
# 0                                        Hand tools
# 1  SOIL WORKING IN AGRICULTURE OR FORESTRY;PARTS,...
# 2  AGRICULTURE;FORESTRY;ANIMAL HUSBANDRY;HUNTING;...
# 3                                  HUMAN NECESSITIES

# %%
df=pd.read_json("C:\\Users\\pooja\\Downloads\\JSONFiles\\A\\A01.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df=pd.read_json("C:\\Users\\pooja\\Downloads\\JSONFiles\\A\\A01.json")
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
#    1028         infer_objects=False, dtype_backend=self.dtype_backend
#    1029     )
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\io\json\_json.py:1402, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
# -> 1402     self.obj = DataFrame(
#    1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\envs\textanalysis\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
d
