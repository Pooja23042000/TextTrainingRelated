# %%
import os
import json

# %%
def get_cpc_labels(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path=os.path.join(folder_path,filename)
            with open(file_path,'r') as file:
                data=json.load(file)
                if "cpc_labels" in data:
                    cpc_labels.append(data["cpc_labels"])

folder_path= "C:\\Users\\pooja\\Downloads\\TextDataset"
print(folder_path)
cpc_labels=[]
get_cpc_labels(folder_path)
# Out:
# C:\Users\pooja\Downloads\TextDataset

# %%
cpc_labels=[list for list in cpc_labels if list]

# %%
cpc_labels
# Out:
# [['A61K3334',
#   'A61K314164',
#   'A61K818',
#   'A61K827',
#   'A61K8671',
#   'A61K867',
#   'A61K31327',
#   'A61K31203',
#   'A61K4506',
#   'A61Q19007',
#   'A61Q1910',
#   'A61K90014',
#   'A61Q1704'],
#  ['H04Q110071', 'H04Q110067', 'H04L6918'],
#  ['E04B14114', 'E04B124', 'E04B5023', 'E04B20012484'],
#  ['G02F1141'],
#  ['H04B10616'],
#  ['B23D59001',
#   'B27B31003',
#   'B27B31006',
#   'B27L700',
#   'G01B5043',
#   'G01B11043',
#   'G01B1700'],
#  ['H03K179622', 'G01N27228', 'G06F13231', 'G06F303543'],
#  ['H01L41193',
#   'C08G1873',
#   'C08G1842',
#   'C08G1844',
#   'H01L4145',
#   'H01L4109',
#   'H01L411132',
#   'H01L41113'],
#  ['A61K3826'],
#  ['G06F17504', 'G06F221710'],
#  ['A61M530', 'A61M52053', 'A61M20053104'],
#  ['G01N21643', 'G01N2178', 'G01N331886', 'G01N31223', 'G01N20217786'],
#  ['G06F93806',
#   'G06F120875',
#   'G06F930029',
#   'G06F93869',
#   'G06F930047',
#   'G06F930018',
#   'G06F22121016',
#   'G06F2212452'],
# ...

# %%
from funcy import flatten

# %%
pip install funcy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
flat_list=flatten(cpc_labels)

# %%
for i in flat_list:
    print(i)
# Out:
# A61K3334
# A61K314164
# A61K818
# A61K827
# A61K8671
# A61K867
# A61K31327
# A61K31203
# A61K4506
# A61Q19007
# A61Q1910
# A61K90014
# A61Q1704
# H04Q110071
# H04Q110067
# H04L6918
# E04B14114
# E04B124
# E04B5023
# E04B20012484
# G02F1141
# H04B10616
# B23D59001
# B27B31003
# B27B31006
# B27L700
# G01B5043
# G01B11043
# G01B1700
# H03K179622
# G01N27228
# G06F13231
# G06F303543
# H01L41193
# C08G1873
# C08G1842
# C08G1844
# H01L4145
# H01L4109
# H01L411132
# H01L41113
# A61K3826
# G06F17504
# G06F221710
# A61M530
# A61M52053
# A61M20053104
# G01N21643
# G01N2178
# G01N331886
# G01N31223
# G01N20217786
# G06F93806
# G06F120875
# G06F930029
# G06F93869
# G06F930047
# G06F930018
# G06F22121016
# G06F2212452
# A61B502416
# A61B51455
# A61B57264
# A61B502007
# F03G604
# F24J20488
# G06F30481
# G06Q20327
# H04W4008
# H04B50031
# H04B50056
# G06Q203821
# H04W1206
# H04W1202
# G06F304883
# G06F3044
# G06F220304105
# G06F220304101
# G06F220304104
# C12Q16806
# H02P942
# H02K127
# H02K112
# ...

# %%
dict={'G06F93/0047':'hiiii','A61B50/2416':'hello'}

# %%
val="A61B572/64"
new_val=re.sub(r'[^a-zA-Z0-9]','',val)
new_val
# Out:
# 'A61B57264'

# %%
import re
result1={}
for key,val in dict.items():
    new_key=re.sub(r'[^a-zA-Z0-9]','',key)
    print(new_key)
    print(val)
    result1[new_key]=val
result1
# Out:
# G06F930047
# hiiii
# A61B502416
# hello
# G06F930047
# hiiii
# A61B502416
# hello
# {'G06F930047': 'hiiii', 'A61B502416': 'hello'}

# %%
import re

def clean_key(key):
    # Using regular expression to remove non-alphanumeric characters
    return re.sub(r'[^a-zA-Z0-9]', '', key)

def clean_dictionary_keys(dictionary):
    cleaned_dict = {}
    for key, value in dictionary.items():
        cleaned_key = clean_key(key)
        cleaned_dict[cleaned_key] = value
    return cleaned_dict

# Example dictionary
my_dict = {
    "key1!": 1,
    "key2@": 2,
    "key3#": 3,
    "key4$": 4,
    "key5%": 5
}

cleaned_dict = clean_dictionary_keys(my_dict)
print(cleaned_dict)
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4, 'key5': 5}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 dict['G06F930047']
#
# KeyError: 'G06F930047'
